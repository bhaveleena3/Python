# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib as plt
import seaborn as sn

# %%
data=pd.read_csv('/content/Q7.csv')
data
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
data.mean()
# Out:
# <ipython-input-7-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-8-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
import statistics as st
print('Mode of Points:',(st.mode(data['Points'])))
print('Mode of Score :',(st.mode(data['Score'])))
print('Mode of Weigh:',(st.mode(data['Weigh'])))
# Out:
# Mode of Points: 3.92
# Mode of Score : 3.44
# Mode of Weigh: 17.02

# %%
data.var()
# Out:
# <ipython-input-10-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
data.std()
# Out:
# <ipython-input-11-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
Points_Range=data.Points.max()-data.Points.min()
Score_Range=data.Score.max()-data.Score.min()
Weigh_Range=data.Weigh.max()-data.Weigh.min()
print(Points_Range,Score_Range,Weigh_Range)
# Out:
# 2.17 3.9110000000000005 8.399999999999999

# %%
#Assignmeent 08
import numpy as np

values =[108,110,123,134,135,145,167,187,199]
probs =0.1111
def expected_value(values, weights):
    values = np.asarray(values)
    weights = np.asarray(weights)
    return (values * weights).sum()

#avg = (sum(weitghs))/len(weitghs)

print("ex value:",expected_value(values, probs))
#print('Expected Value of the Weight of that patient:',exp)
# Out:
# ex value: 145.3188

# %%
sum(weitghs)
# Out:
# 1308

# %%
len(weitghs)
# Out:
# 9
